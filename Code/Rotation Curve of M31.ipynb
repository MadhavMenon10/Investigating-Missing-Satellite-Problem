# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
r = [5.68, 6.81, 7.95, 9.08, 10.22, 11.35, 12.49, 13.62, 14.76, 15.89, 17.03, 18.16, 19.3, 20.43, 21.45, 22.47, 23.50, 24.52, 25.54, 26.56, 27.58, 28.60, 29.62, 30.65, 31.67, 32.69, 33.71, 34.73]
v = [235.5, 242.9, 251.1, 262, 258.9, 255.1, 251.8, 252.1, 251, 245.5, 232.8, 232, 235.7, 229.3, 227.6, 226.0, 225.7, 227.5, 227.4, 225.6, 224.4, 222.3, 222.1, 224.9, 228.1, 231.1, 230.4, 226.8]
Δv = [17.8, 0.8, 0.7, 2.1, 6.9, 5.7, 17.1, 7.4, 18.6, 28.8, 1.0, 14.2, 4.6, 13.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8, 28.8]
# v_max = []
# v_min = []
# for i in range(0, len(v)):
#     v_max.append(v[i]+Δv[i])
#     v_min.append(v[i]-Δv[i])
v_error = [Δv, Δv]
plt.ylim(0, 300)
plt.plot(r, v)
plt.errorbar(r, v, yerr=v_error, fmt="o", color="black", capsize=2)
plt.xlabel("R (kpc)")
plt.ylabel("v (kms$^-1$)")
plt.title("Rotation curve of M31")
plt.savefig('RotationCurveM31.jpg',bbox_inches='tight')
plt.show()
